# %% [markdown]
# RECOGNITION OF TAMIL ACTOR USING PCA AND SVM

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install scikit-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
dhruv=os.listdir("C:/Users/ADMIN/Desktop/DHRUVVIKRAM")

# %%
limit=7
dhruv_images=[None]*limit
j=0
for i in dhruv:
    if(j<limit):
        dhruv_images[j]=imread("C:/Users/ADMIN/Desktop/DHRUVVIKRAM/"+i)
        j+=1
    else:
        break

# %%
imshow(dhruv_images[5])

# %%
siva=os.listdir("C:/Users/ADMIN/Desktop/siva/")

# %%
siva_images=[None]*limit
j=0
for i in siva:
    if(j<limit):
        siva_images[j]=imread("C:/Users/ADMIN/Desktop/siva/"+i)
        j+=1
    else:
        break

# %%
imshow(siva_images[5])

# %%
karthik=os.listdir("C:/Users/ADMIN/Desktop/karthik/")

# %%
karthik_images=[None]*limit
j=0
for i in karthik:
    if(j<limit):
        karthik_images[j]=imread("C:/Users/ADMIN/Desktop/karthik/"+i)
        j+=1
    else:
        break

# %%
imshow(karthik_images[4])

# %%
dhruv_gray=[None]*limit
j=0
for i in dhruv:
    if(j<limit):
        dhruv_gray[j]=rgb2gray(dhruv_images[j])
        j+=1
    else:
        break

# %%
imshow(dhruv_images[4])

# %%
dhruv_gray[2].shape
# Out:
# (180, 157)

# %%
dhruv_gray[3].shape
# Out:
# (180, 165)

# %%
dhruv_gray[1].shape
# Out:
# (180, 237)

# %%
for j in range (7):
    dhruv=dhruv_gray[j]
    dhruv_gray[j]=resize(dhruv,(500,500))

# %%
images_size_dhruv=dhruv_gray[3].shape

# %%
flatten_size_dhruv=images_size_dhruv[0]*images_size_dhruv[1]

# %%
flatten_size_dhruv
# Out:
# 250000

# %%
imshow(dhruv_gray[4])

# %%
flatten_size_dhruv
# Out:
# 250000

# %%
for i in range(len_of_images_dhruv):
    dhruv_gray[i]=np.ndarray.flatten(dhruv_gray[i]).reshape(flatten_size_dhruv,1)

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
dhruv_gray=np.dstack(dhruv_gray)

# %%
dhruv_gray.shape
# Out:
# (250000, 1, 7)

# %%
dhruv_gray=np.rollaxis(dhruv_gray,axis=2,start=0)

# %%
dhruv_gray.shape
# Out:
# (7, 250000, 1)

# %%
dhruv_gray=dhruv_gray.reshape(len_of_images_dhruv,flatten_size_dhruv)

# %%
dhruv_gray.shape
# Out:
# (7, 250000)

# %%
dhruv_data=pd.DataFrame(dhruv_gray)

# %%
dhruv_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.359625  0.358809  0.356480  0.356480  0.355625  0.353256  0.354229
# 1  0.422560  0.422968  0.419250  0.415576  0.411988  0.409209  0.409209
# 2  0.197265  0.224010  0.202205  0.175460  0.148714  0.135571  0.127641
# 3  0.849988  0.849988  0.849988  0.849988  0.849988  0.849988  0.849988
# 4  0.249964  0.249799  0.249106  0.247095  0.245087  0.245087  0.245321
# 5  0.992158  0.989646  0.984030  0.981167  0.981012  0.983124  0.981173
# 6  0.027984  0.028094  0.030110  0.032923  0.036309  0.037541  0.037541
#
#      7         8         9       ...    249990    249991    249992    249993  \
# 0  0.356598  0.358966  0.362268  ...  0.511689  0.509443  0.508707  0.507119
# 1  0.409471  0.411725  0.413956  ...  0.119600  0.119627  0.119627  0.119627
# 2  0.119711  0.121537  0.131732  ...  0.394395  0.356995  0.329974  0.315052
# 3  0.849988  0.849988  0.849988  ...  0.473555  0.473555  0.473555  0.473555
# ...
