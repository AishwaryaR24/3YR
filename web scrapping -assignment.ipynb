# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as rq

# %%
url ="https://www.nykaa.com/bestsellers/c/15752?transaction_id=f082ad990edb16f5801d2ed0f57f5a09&intcmp=nykaa:hp:desktop-homepage:default:bestsellers-title:COLUMN_GRID_V2:10:Header:-1:f082ad990edb16f5801d2ed0f57f5a09"

# %%
request = rq.get(url)
request
# Out:
# <Response [200]>

# %%
html = bs(request.text)
html
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1.0,maximum-scale=5.0" name="viewport"/><meta content="#fff" name="theme-color"/><meta content="NykaaFrontendTeam" name="author"/><script type="text/javascript">
# ;window.NREUM||(NREUM={});NREUM.init={distributed_tracing:{enabled:true},privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]}};
#
# ;NREUM.loader_config={accountID:"1225159",trustKey:"1225159",agentID:1001474717,licenseKey:"a3a71d91f4",applicationID:1001474717};
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"a3a71d91f4",applicationID:1001474717,sa:1};
# ...

# %%
html = bs(request.text)

# %%
titles = html.select(".css-xrzmfa")
price = html.select(".css-111z9ua")
rating= html.select(".css-1qbvrhp")

# %%
Details = pd.DataFrame(titles,columns=[" product Name"])
Details["Price"] = price
Details["rating"] = rating

# %%
titles
# Out:
# [<div class="css-xrzmfa">Nykaa Prep Me Up! Face Primer</div>,
#  <div class="css-xrzmfa">Maybelline New York Volum Express Hyper Curl Mascara - Washa...</div>,
#  <div class="css-xrzmfa">M.A.C Studio Fix Fluid SPF 15</div>,
#  <div class="css-xrzmfa">Aqualogica Glow+ Dewy Sunscreen with Papaya &amp; Vitamin C - SP...</div>,
#  <div class="css-xrzmfa">SUGAR Contour De Force Face Palette</div>,
#  <div class="css-xrzmfa">L'Oreal Paris Revitalift Hydrating Serum With 1.5 % Hyaluron...</div>,
#  <div class="css-xrzmfa">Bath &amp; Body Works Japanese Cherry Blossom Daily Nourishing B...</div>,
#  <div class="css-xrzmfa">L'Oreal Professionnel X-Tenso Care Shampoo For Smooth, Manag...</div>,
#  <div class="css-xrzmfa">Nykaa Cosmetics All Day Matte Waterproof, Transfer Proof, 12...</div>,
#  <div class="css-xrzmfa">Lakme Absolute Blur Perfect Makeup Primer</div>,
#  <div class="css-xrzmfa">Wella Professionals Elements Renewing Shampoo (Zero Sulfates...</div>,
# ...

# %%
price
# Out:
# [<span class="css-111z9ua">₹467</span>,
#  <span class="css-111z9ua">₹345</span>,
#  <span class="css-111z9ua">₹3300</span>,
#  <span class="css-111z9ua">₹351</span>,
#  <span class="css-111z9ua">₹695</span>,
#  <span class="css-111z9ua">₹476</span>,
#  <span class="css-111z9ua">₹1129</span>,
#  <span class="css-111z9ua">₹650</span>,
#  <span class="css-111z9ua">₹271</span>,
#  <span class="css-111z9ua">₹619</span>,
#  <span class="css-111z9ua">₹1058</span>,
#  <span class="css-111z9ua">₹539</span>,
#  <span class="css-111z9ua">₹599</span>,
#  <span class="css-111z9ua">₹278</span>,
#  <span class="css-111z9ua">₹100</span>,
#  <span class="css-111z9ua">₹300</span>,
#  <span class="css-111z9ua">₹100</span>,
#  <span class="css-111z9ua">₹165</span>,
#  <span class="css-111z9ua">₹1233</span>,
#  <span class="css-111z9ua">₹247</span>]

# %%
rating
# Out:
# [<span class="css-1qbvrhp">(<!-- --> <!-- -->18843<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->72755<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->9639<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->27545<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->13504<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->24516<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->134<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->18837<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->24098<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->38790<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->2081<!-- --> <!-- -->)</span>,
#  <span class="css-1qbvrhp">(<!-- --> <!-- -->5773<!-- --> <!-- -->)</span>,
# ...

# %%
Details = pd.DataFrame(titles,columns=[" product Name"])
Details["Price"] = price
Details["rating"] = rating
Details
# Out:
#                                          product Name    Price  \
# 0                       Nykaa Prep Me Up! Face Primer   [₹467]
# 1   Maybelline New York Volum Express Hyper Curl M...   [₹345]
# 2                       M.A.C Studio Fix Fluid SPF 15  [₹3300]
# 3   Aqualogica Glow+ Dewy Sunscreen with Papaya & ...   [₹351]
# 4                 SUGAR Contour De Force Face Palette   [₹695]
# 5   L'Oreal Paris Revitalift Hydrating Serum With ...   [₹476]
# 6   Bath & Body Works Japanese Cherry Blossom Dail...  [₹1129]
# 7   L'Oreal Professionnel X-Tenso Care Shampoo For...   [₹650]
# 8   Nykaa Cosmetics All Day Matte Waterproof, Tran...   [₹271]
# 9           Lakme Absolute Blur Perfect Makeup Primer   [₹619]
# 10  Wella Professionals Elements Renewing Shampoo ...  [₹1058]
# 11    Mamaearth Onion Hair Mask For Hair Fall Control   [₹539]
# 12  Minimalist SPF 60 PA ++++ Sunscreen With Antio...   [₹599]
# 13             Plum Bodylovin' Vanilla Vibes Body Oil   [₹278]
# ...
